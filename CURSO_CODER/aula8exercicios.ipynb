# %% [markdown]
# 1. Abra o arquivo "Cancer_Data.csv", conte quantos linhas o dataframe possui com a coluna diagnosis = 'B'.

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('Cancer_Data.csv')

# %%
df1.head(2)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
# 1  842517         M        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
# 1  ...          23.41            158.8      1956.0            0.1238
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
#
#    fractal_dimension_worst  Unnamed: 32
# ...

# %%
df1.loc[df1['diagnosis'] == 'B', 'diagnosis'].count() #OUTRO JEITO
# Out:
# 357

# %%
df1[df1['diagnosis'] == 'B'] #OUTRO JEITO
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19    8510426         B       13.540         14.36           87.46      566.3
# 20    8510653         B       13.080         15.71           85.63      520.0
# 21    8510824         B        9.504         12.44           60.34      273.9
# 37     854941         B       13.030         18.42           82.61      523.8
# 46   85713702         B        8.196         16.84           51.71      201.9
# ..        ...       ...          ...           ...             ...        ...
# 558    925277         B       14.590         22.68           96.39      657.1
# 559    925291         B       11.510         23.93           74.52      403.5
# 560    925292         B       14.050         27.15           91.38      600.4
# 561    925311         B       11.200         29.37           70.67      386.0
# 568     92751         B        7.760         24.54           47.92      181.0
#
# ...

# %%
df1[df1['diagnosis'] == 'B'].shape[0] #OUTRO JEITO
# Out:
# 357

# %% [markdown]
# 2. Substitua a coluna diagnosis seguindo a regra:
#  - “B” para “benign cancer”
#  - “M” para “malignant cancer”

# %%
df1.head(1)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.1184            0.2776          0.3001               0.1471
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
#
#    fractal_dimension_worst  Unnamed: 32
# 0                   0.1189          NaN
#
# [1 rows x 33 columns]

# %%
df1['diagnosis'] = df1['diagnosis'].str.replace('B','benign cancer')

# %%
df1.head(10)
# Out:
#          id         diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0    842302  malignant cancer        17.99         10.38          122.80
# 1    842517  malignant cancer        20.57         17.77          132.90
# 2  84300903  malignant cancer        19.69         21.25          130.00
# 3  84348301  malignant cancer        11.42         20.38           77.58
# 4  84358402  malignant cancer        20.29         14.34          135.10
# 5    843786  malignant cancer        12.45         15.70           82.57
# 6    844359  malignant cancer        18.25         19.98          119.60
# 7  84458202  malignant cancer        13.71         20.83           90.20
# 8    844981  malignant cancer        13.00         21.82           87.50
# 9  84501001  malignant cancer        12.46         24.04           83.97
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     1001.0          0.11840           0.27760         0.30010
# ...

# %%
df1['diagnosis'] = df1['diagnosis'].str.replace('M','malignant cancer')

# %%
df1.head(20)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M        17.99         10.38          122.80     1001.0
# 1     842517         M        20.57         17.77          132.90     1326.0
# 2   84300903         M        19.69         21.25          130.00     1203.0
# 3   84348301         M        11.42         20.38           77.58      386.1
# 4   84358402         M        20.29         14.34          135.10     1297.0
# 5     843786         M        12.45         15.70           82.57      477.1
# 6     844359         M        18.25         19.98          119.60     1040.0
# 7   84458202         M        13.71         20.83           90.20      577.9
# 8     844981         M        13.00         21.82           87.50      519.8
# 9   84501001         M        12.46         24.04           83.97      475.9
# 10    845636         M        16.02         23.24          102.70      797.8
# ...

# %%
df1['diagnosis'].value_counts() #FAZER A CONTAGEM
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [markdown]
# 3. Filtre os IDs dos "malignant cancer" com raio maior que 25.

# %%
df1.loc[(df1['diagnosis'] == "malignant cancer") & (df1['radius_mean'] > 25),'id']
# Out:
# 82       8611555
# 180       873592
# 212      8810703
# 352       899987
# 461    911296202
# Name: id, dtype: int64
